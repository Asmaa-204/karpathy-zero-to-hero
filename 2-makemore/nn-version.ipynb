# %%
import torch
import torch.nn.functional as F

# %%
words = open('names.txt', 'r').read().splitlines()

# %%
# char to integer mapping
chars = sorted(list(set(''.join(words))))
stoi = {s:i+1 for i,s in enumerate(chars)}
stoi["."] = 0 

# integer to char mapping
itos = {i:s for s,i in stoi.items()}

# %% [markdown]
# ## Note:
# - in the NN version, the input is the first letter, the output is the second letter
# - possible outputs are 27 (27 Neurons in the layer)
# - thus a `softmax` will be used at the output layer

# %%
xs, ys = [], []

# %%
for word in words[:1]:
    word = "." + word + "."
    for ch1, ch2 in zip(word, word[1:]):
        xs.append(stoi[ch1])
        ys.append(stoi[ch2])

# %%
xs = torch.tensor(xs)
ys = torch.tensor(ys)
num = xs.nelement()

xenc = F.one_hot(xs, num_classes=27).to(torch.float32)
xenc.shape
# Out:
# torch.Size([5, 27])

# %%
g = torch.Generator().manual_seed(2147483647)
w = torch.randn((27, 27), requires_grad=True)
w
# Out:
# tensor([[-2.4417e-01,  1.3433e-01,  8.4862e-01, -3.0046e-03,  1.0235e+00,
#           2.5525e-01, -7.2576e-01,  9.8405e-01, -8.3659e-01, -6.4309e-01,
#          -1.2482e+00,  8.4320e-02,  5.0813e-01,  4.1696e-01, -6.0930e-01,
#          -1.0574e-01, -1.3805e-01,  6.7191e-01,  2.2708e-01,  5.9487e-01,
#           1.0616e+00,  1.2016e+00, -3.8013e-01, -2.0156e+00,  1.6827e+00,
#           4.8591e-01, -5.2556e-02],
#         [ 8.4453e-01, -9.9432e-02, -1.0253e+00,  6.9441e-02, -2.0995e+00,
#           1.9292e+00, -1.7391e+00, -9.5256e-01,  3.6268e-03,  3.0155e-01,
#           1.4338e+00,  2.0275e+00, -2.6807e+00, -8.2516e-01,  1.7354e-02,
#           7.8567e-01,  5.1407e-01, -1.2878e+00,  7.0497e-02,  2.6389e-01,
#          -8.8480e-01, -1.5451e+00, -5.7936e-02,  1.0274e-01,  9.7375e-01,
#           1.1783e+00, -1.2412e-01],
#         [-1.4523e+00, -1.9335e-01,  1.4256e+00,  5.5516e-01,  2.3064e+00,
#           1.3092e-01, -6.7584e-01, -1.3463e+00, -5.7315e-01, -2.1701e+00,
#           8.4077e-01,  1.4423e+00, -1.1496e+00, -5.3071e-01,  1.2885e+00,
#          -1.2284e+00,  4.2199e-01,  7.6905e-01,  7.8043e-01, -6.2936e-01,
#           1.4360e+00,  1.4328e-01, -7.4374e-01, -2.4425e-01, -8.6536e-02,
#           2.3545e+00, -4.4958e-01],
#         [ 3.6656e-01,  4.6906e-01, -8.3642e-01, -9.8442e-01,  7.6130e-01,
#           4.5024e-01, -4.5655e-01,  8.9249e-01, -1.2528e+00, -4.5201e-02,
#           2.7794e+00,  1.4154e+00,  4.2436e-01,  1.2205e+00,  1.9889e+00,
#          -1.4832e+00, -2.6452e+00, -6.9464e-02, -1.4344e+00, -1.3032e+00,
#           2.1477e+00, -1.6665e+00, -2.7776e-02, -9.9717e-01, -5.1958e-01,
#          -1.2287e+00, -1.9821e+00],
#         [ 1.1721e+00,  1.5660e+00, -1.0193e+00,  3.9716e-01, -9.7218e-01,
#           5.2295e-01, -3.2915e-01, -1.1786e+00, -1.3080e+00,  8.3901e-01,
#           1.3075e+00,  3.6131e-01,  1.5772e+00,  2.8410e-01,  7.9972e-01,
#          -3.1297e-01, -5.3776e-01,  3.1715e-01,  1.6339e+00, -2.7862e-03,
#          -1.8899e-01, -6.5605e-01,  2.0567e-01,  7.6448e-02, -1.3607e-02,
#          -4.3912e-01, -4.4624e-01],
#         [-1.4569e-01, -8.1181e-01, -1.0132e+00,  1.9174e+00, -1.1514e+00,
#          -3.6777e-01,  2.0409e+00, -9.1438e-01,  9.7282e-01,  6.1550e-01,
#          -6.6257e-01,  9.5815e-01, -4.1556e-01, -2.5010e-01,  5.3631e-01,
#           8.1923e-01,  3.8817e-01,  2.0247e+00,  1.1356e-01, -8.5503e-01,
#           9.6129e-02,  1.3154e+00, -1.1427e+00, -1.9404e-01, -1.0626e+00,
#           1.2710e+00,  2.1193e-01],
#         [ 5.9731e-01,  7.2668e-01,  2.1048e-01,  1.4098e+00,  3.7732e-01,
#          -1.2947e+00, -2.4845e+00,  5.7149e-01,  9.3586e-02,  6.2746e-01,
#          -1.2366e+00, -8.6321e-01, -1.1440e-02, -6.7469e-01,  1.4087e-01,
#          -4.4245e-02,  6.7435e-01,  6.9173e-01, -1.4527e+00,  9.7224e-01,
#           1.3036e-01, -2.5792e+00, -3.5153e-01, -3.4170e-01, -1.6896e+00,
#           1.5277e+00,  2.7634e-01],
#         [ 6.1224e-01,  2.2664e-01, -1.9776e+00, -1.2904e+00, -1.4207e+00,
#           1.2772e+00, -8.7790e-01, -1.8627e+00, -1.7961e+00,  2.6012e-01,
#          -1.6099e+00,  1.6280e+00, -2.4928e+00,  3.9627e-01, -1.8943e-01,
#          -4.0301e-01,  1.0021e+00,  9.7577e-01,  1.2346e+00,  7.2459e-02,
#           7.5277e-01,  5.5188e-01,  1.3859e+00,  1.3157e+00, -1.4291e+00,
#           5.0297e-01,  2.1544e+00],
#         [-9.3723e-01,  8.2452e-01,  9.7030e-01, -2.0904e+00,  9.4738e-01,
#           8.4105e-03,  4.8844e-01,  6.2500e-01,  1.0727e-01,  1.6527e-01,
#           4.3763e-02,  1.1093e-01,  8.3144e-01,  1.6637e-02,  1.4444e-01,
#           5.7283e-01, -9.1951e-02,  1.7707e+00,  1.1000e+00, -1.0909e-01,
#          -1.6806e+00,  3.1778e-03, -1.5948e-01, -3.1968e-02, -1.6598e+00,
#          -3.7898e-01,  7.3792e-02],
#         [ 8.2702e-01,  1.1635e+00, -2.3383e+00,  2.5188e-01,  4.9166e-01,
#          -2.5518e-01, -9.4955e-03,  1.8730e+00,  6.8552e-01,  5.4778e-01,
#          -3.5271e-01, -3.0063e+00, -1.5500e-01, -3.7900e-01,  1.3129e+00,
#          -1.6104e-01, -3.5574e-01,  1.2820e+00,  5.8137e-01, -1.6913e-01,
#           3.0642e-01, -3.5152e-01,  8.3984e-01, -1.4106e+00, -1.2984e+00,
#           3.1571e-01,  9.3970e-01],
#         [-1.2889e+00, -1.4514e+00,  3.1786e+00,  1.2680e+00, -1.3356e+00,
#          -2.2807e-02,  3.6189e-01, -5.3017e-02, -1.0373e+00,  3.5507e-01,
#           2.3509e-01,  1.0082e+00,  1.5138e+00, -1.3435e+00,  6.6598e-01,
#           1.7952e+00, -6.6034e-01,  1.2767e+00,  5.1048e-01,  1.2397e-01,
#          -3.8509e-01,  1.1439e+00, -2.2610e+00, -4.3951e-01,  9.8476e-01,
#          -9.2401e-01, -1.8046e+00],
#         [ 5.0101e-01, -1.5507e+00,  4.4187e-01, -1.6932e+00,  5.7555e-01,
#          -5.6104e-01, -7.3073e-01, -9.0590e-01,  1.0103e-01,  1.7140e+00,
#           7.5702e-02,  8.4243e-01, -2.0217e+00, -1.2562e-01, -3.8319e-01,
#           8.2183e-01,  1.3952e+00, -8.6450e-01,  3.1829e-01,  2.5419e-01,
#          -8.7195e-01, -1.0073e+00,  9.2404e-01,  7.3824e-01,  5.0457e-01,
#          -1.5802e-01, -6.2800e-01],
#         [ 1.4782e-01,  1.4711e-04, -6.5816e-01, -9.1256e-01, -9.3944e-01,
#           1.6047e+00,  3.1973e-01, -7.9983e-01, -1.8890e-01,  6.2041e-02,
#           1.2100e+00,  1.7964e+00, -1.4381e+00,  6.2341e-01,  1.7174e-01,
#           4.8048e-01,  1.3422e+00,  1.5630e-01,  8.3223e-01,  3.9046e-01,
#           1.7686e+00, -2.1825e-01, -4.7431e-01,  7.6809e-01, -6.3996e-01,
#           1.0676e+00, -1.5760e+00],
#         [ 5.9843e-01,  2.9922e-01,  2.9480e-01, -1.8480e+00,  4.3865e-01,
#           1.4787e+00,  3.4717e-01,  1.7010e+00,  1.6587e-01,  1.1648e+00,
#           1.5958e+00, -9.8388e-02,  9.9252e-01, -2.9795e-01,  7.9178e-01,
#           2.8524e-01, -2.9559e-01, -2.7456e-01, -8.0726e-01,  4.9152e-01,
#           1.1352e+00, -1.2793e+00,  2.6242e-01,  6.4480e-01, -1.5259e+00,
#          -7.7624e-01,  8.4564e-01],
#         [-1.5506e-01,  5.2734e-01,  8.1999e-01,  5.9854e-01,  1.0998e+00,
#          -6.1361e-02,  2.9600e+00,  9.3531e-01,  8.0539e-01, -5.7754e-01,
#          -1.5240e+00,  1.0614e+00,  1.3384e-01, -9.4410e-01, -2.2024e-01,
#           1.0972e+00, -1.5837e+00, -9.2632e-01,  9.8872e-01,  4.7618e-01,
#           1.7201e+00,  1.5364e+00, -3.9286e-02,  3.0317e-01, -1.0846e+00,
#          -3.3599e-02, -5.4791e-01]], requires_grad=True)

# %%
softmax = torch.nn.Softmax(dim=1)

# putting every thing together
for k in range(10):
  # forward pass
  logits = xenc @ w
  y_predict = softmax(logits)

  q = y_predict[torch.arange(num), ys]
  loss = sum(-torch.log(q)).mean()
    
  print(loss.item())
  
  # backward pass
  w.grad = None
  loss.backward()
  w.data += -0.1 * w.grad
# Out:
# 18.91659927368164
# 18.39274787902832
# 17.873640060424805
# 17.3596134185791
# 16.851016998291016
# 16.348228454589844
# 15.851648330688477
# 15.361690521240234
# 14.878787994384766
# 14.403383255004883
